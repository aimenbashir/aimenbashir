# %%
#multivarient
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y1=[6,7,8,9,10]
y2=[11,12,13,14,15]
y3=[16,17,18,19,20]
plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)
plt.xlabel('x-axix')
plt.ylabel('y-axis')
plt.show()
